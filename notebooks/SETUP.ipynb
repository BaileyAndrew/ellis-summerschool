# %% [markdown]
# # Tutorial Setup
#
# This notebook should be run once, as early as possible.  It will download all Python packages the attendees need, as well as the data.  If they have not downloaded the data before, it will take a couple minutes.  After downloading the data, even if they leave Codespaces it will still be stored in Codespaces, so this only needs to be run once.
#
# After successfully running this notebook, one can move on to `TUTORIAL.ipynb`, in which attendees will be able to analyze the dataset with the algorithms talked about in the presentations.

# %%
# Install all required packages
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: ipywidgets==8.1.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from -r ../requirements.txt (line 1)) (8.1.2)
# Requirement already satisfied: matplotlib==3.8.4 in /home/codespace/.python/current/lib/python3.12/site-packages (from -r ../requirements.txt (line 2)) (3.8.4)
# Requirement already satisfied: pandas==2.2.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from -r ../requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: tqdm==4.66.4 in /home/codespace/.python/current/lib/python3.12/site-packages (from -r ../requirements.txt (line 4)) (4.66.4)
# Requirement already satisfied: scanpy==1.10 in /home/codespace/.python/current/lib/python3.12/site-packages (from -r ../requirements.txt (line 5)) (1.10.0)
# Requirement already satisfied: GmGM==0.5.6 in /home/codespace/.python/current/lib/python3.12/site-packages (from -r ../requirements.txt (line 6)) (0.5.6)
# Requirement already satisfied: python-igraph in /home/codespace/.python/current/lib/python3.12/site-packages (from -r ../requirements.txt (line 7)) (0.11.8)
# Requirement already satisfied: leidenalg in /home/codespace/.python/current/lib/python3.12/site-packages (from -r ../requirements.txt (line 8)) (0.10.2)
# Requirement already satisfied: scikit-learn in /home/codespace/.local/lib/python3.12/site-packages (from -r ../requirements.txt (line 9)) (1.6.1)
# Requirement already satisfied: pybiomart in /home/codespace/.python/current/lib/python3.12/site-packages (from -r ../requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: gprofiler-official in /home/codespace/.python/current/lib/python3.12/site-packages (from -r ../requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: comm>=0.1.3 in /home/codespace/.local/lib/python3.12/site-packages (from ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (9.0.2)
# Requirement already satisfied: traitlets>=4.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/codespace/.python/current/lib/python3.12/site-packages (from ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (4.0.14)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/codespace/.python/current/lib/python3.12/site-packages (from ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (3.0.15)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib==3.8.4->-r ../requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib==3.8.4->-r ../requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib==3.8.4->-r ../requirements.txt (line 2)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib==3.8.4->-r ../requirements.txt (line 2)) (1.4.8)
# Requirement already satisfied: numpy>=1.21 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib==3.8.4->-r ../requirements.txt (line 2)) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib==3.8.4->-r ../requirements.txt (line 2)) (24.2)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib==3.8.4->-r ../requirements.txt (line 2)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib==3.8.4->-r ../requirements.txt (line 2)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib==3.8.4->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas==2.2.2->-r ../requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas==2.2.2->-r ../requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: anndata>=0.8 in /home/codespace/.python/current/lib/python3.12/site-packages (from scanpy==1.10->-r ../requirements.txt (line 5)) (0.11.4)
# Requirement already satisfied: h5py>=3.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from scanpy==1.10->-r ../requirements.txt (line 5)) (3.13.0)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.12/site-packages (from scanpy==1.10->-r ../requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: legacy-api-wrap>=1.4 in /home/codespace/.python/current/lib/python3.12/site-packages (from scanpy==1.10->-r ../requirements.txt (line 5)) (1.4.1)
# Requirement already satisfied: natsort in /home/codespace/.python/current/lib/python3.12/site-packages (from scanpy==1.10->-r ../requirements.txt (line 5)) (8.4.0)
# Requirement already satisfied: networkx>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from scanpy==1.10->-r ../requirements.txt (line 5)) (3.3)
# Requirement already satisfied: numba>=0.56 in /home/codespace/.python/current/lib/python3.12/site-packages (from scanpy==1.10->-r ../requirements.txt (line 5)) (0.61.2)
# Requirement already satisfied: patsy in /home/codespace/.python/current/lib/python3.12/site-packages (from scanpy==1.10->-r ../requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5 in /home/codespace/.python/current/lib/python3.12/site-packages (from scanpy==1.10->-r ../requirements.txt (line 5)) (0.5.13)
# Requirement already satisfied: scipy>=1.8 in /home/codespace/.local/lib/python3.12/site-packages (from scanpy==1.10->-r ../requirements.txt (line 5)) (1.15.2)
# Requirement already satisfied: seaborn>=0.13 in /home/codespace/.local/lib/python3.12/site-packages (from scanpy==1.10->-r ../requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: session-info in /home/codespace/.python/current/lib/python3.12/site-packages (from scanpy==1.10->-r ../requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: statsmodels>=0.13 in /home/codespace/.python/current/lib/python3.12/site-packages (from scanpy==1.10->-r ../requirements.txt (line 5)) (0.14.4)
# Requirement already satisfied: umap-learn!=0.5.0,>=0.5 in /home/codespace/.python/current/lib/python3.12/site-packages (from scanpy==1.10->-r ../requirements.txt (line 5)) (0.5.7)
# Requirement already satisfied: dask>=2022.03 in /home/codespace/.python/current/lib/python3.12/site-packages (from GmGM==0.5.6->-r ../requirements.txt (line 6)) (2025.5.1)
# Requirement already satisfied: igraph==0.11.8 in /home/codespace/.python/current/lib/python3.12/site-packages (from python-igraph->-r ../requirements.txt (line 7)) (0.11.8)
# Requirement already satisfied: texttable>=1.6.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from igraph==0.11.8->python-igraph->-r ../requirements.txt (line 7)) (1.7.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn->-r ../requirements.txt (line 9)) (3.6.0)
# Requirement already satisfied: future in /home/codespace/.python/current/lib/python3.12/site-packages (from pybiomart->-r ../requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from pybiomart->-r ../requirements.txt (line 10)) (2.32.3)
# Requirement already satisfied: requests-cache in /home/codespace/.python/current/lib/python3.12/site-packages (from pybiomart->-r ../requirements.txt (line 10)) (1.2.1)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in /home/codespace/.python/current/lib/python3.12/site-packages (from anndata>=0.8->scanpy==1.10->-r ../requirements.txt (line 5)) (1.12.0)
# Requirement already satisfied: click>=8.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from dask>=2022.03->GmGM==0.5.6->-r ../requirements.txt (line 6)) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from dask>=2022.03->GmGM==0.5.6->-r ../requirements.txt (line 6)) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/codespace/.local/lib/python3.12/site-packages (from dask>=2022.03->GmGM==0.5.6->-r ../requirements.txt (line 6)) (2024.6.1)
# Requirement already satisfied: partd>=1.4.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from dask>=2022.03->GmGM==0.5.6->-r ../requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from dask>=2022.03->GmGM==0.5.6->-r ../requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from dask>=2022.03->GmGM==0.5.6->-r ../requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: decorator in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (2.19.1)
# Requirement already satisfied: stack_data in /home/codespace/.local/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/codespace/.python/current/lib/python3.12/site-packages (from numba>=0.56->scanpy==1.10->-r ../requirements.txt (line 5)) (0.44.0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib==3.8.4->-r ../requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->pybiomart->-r ../requirements.txt (line 10)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->pybiomart->-r ../requirements.txt (line 10)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->pybiomart->-r ../requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->pybiomart->-r ../requirements.txt (line 10)) (2025.1.31)
# Requirement already satisfied: attrs>=21.2 in /home/codespace/.local/lib/python3.12/site-packages (from requests-cache->pybiomart->-r ../requirements.txt (line 10)) (25.3.0)
# Requirement already satisfied: cattrs>=22.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from requests-cache->pybiomart->-r ../requirements.txt (line 10)) (25.1.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests-cache->pybiomart->-r ../requirements.txt (line 10)) (4.3.6)
# Requirement already satisfied: url-normalize>=1.4 in /home/codespace/.python/current/lib/python3.12/site-packages (from requests-cache->pybiomart->-r ../requirements.txt (line 10)) (2.2.1)
# Requirement already satisfied: stdlib_list in /home/codespace/.python/current/lib/python3.12/site-packages (from session-info->scanpy==1.10->-r ../requirements.txt (line 5)) (0.11.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/codespace/.local/lib/python3.12/site-packages (from cattrs>=22.2->requests-cache->pybiomart->-r ../requirements.txt (line 10)) (4.12.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/codespace/.local/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: locket in /home/codespace/.python/current/lib/python3.12/site-packages (from partd>=1.4.0->dask>=2022.03->GmGM==0.5.6->-r ../requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/codespace/.local/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pure-eval in /home/codespace/.local/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.1.2->-r ../requirements.txt (line 1)) (0.2.3)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import scanpy as sc
from pathlib import Path
# Out:
# /home/codespace/.python/current/lib/python3.12/site-packages/anndata/utils.py:434: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# /home/codespace/.python/current/lib/python3.12/site-packages/anndata/utils.py:434: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# /home/codespace/.python/current/lib/python3.12/site-packages/anndata/utils.py:434: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# /home/codespace/.python/current/lib/python3.12/site-packages/anndata/utils.py:434: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/codespace/.python/current/lib/python3.12/site-packages/anndata/utils.py:434: FutureWarning: Importing read_mtx from `anndata` is deprecated. Import anndata.io.read_mtx instead.
#   warnings.warn(msg, FutureWarning)
# /home/codespace/.python/current/lib/python3.12/site-packages/anndata/utils.py:434: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   warnings.warn(msg, FutureWarning)
# /home/codespace/.python/current/lib/python3.12/site-packages/anndata/utils.py:434: FutureWarning: Importing read_umi_tools from `anndata` is deprecated. Import anndata.io.read_umi_tools instead.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We'll use scanpy's "built-in" datasets for this workshop.  The next code cell should make sure they are all downloaded.

# %%
sc.datasets.blobs()
# Out:
# AnnData object with n_obs × n_vars = 640 × 11
#     obs: 'blobs'

# %% [markdown]
# We'll use this dataset:
#     https://www.ebi.ac.uk/gxa/sc/experiments/E-GEOD-130148/results/cell-plots
#
# From paper:
#     https://europepmc.org/abstract/MED/31209336

# %%
# This establishes the directory that the data will be saved to
sc._settings.ScanpyConfig.datasetdir = Path('../data/')
adata = sc.datasets.ebi_expression_atlas(
    accession='E-GEOD-130148',
)
adata
# Out:
#   0%|          | 0.00/2.20M [00:00<?, ?B/s]
# 0.00B [00:00, ?B/s]
# AnnData object with n_obs × n_vars = 3566 × 19206
#     obs: 'Sample Characteristic[organism]', 'Sample Characteristic Ontology Term[organism]', 'Sample Characteristic[individual]', 'Sample Characteristic Ontology Term[individual]', 'Sample Characteristic[age]', 'Sample Characteristic Ontology Term[age]', 'Sample Characteristic[sex]', 'Sample Characteristic Ontology Term[sex]', 'Sample Characteristic[organism part]', 'Sample Characteristic Ontology Term[organism part]', 'Sample Characteristic[sampling site]', 'Sample Characteristic Ontology Term[sampling site]', 'Sample Characteristic[disease]', 'Sample Characteristic Ontology Term[disease]', 'Sample Characteristic[disease staging]', 'Sample Characteristic Ontology Term[disease staging]', 'Sample Characteristic[clinical information]', 'Sample Characteristic Ontology Term[clinical information]', 'Factor Value[sampling site]', 'Factor Value Ontology Term[sampling site]', 'Factor Value[disease]', 'Factor Value Ontology Term[disease]', 'Factor Value[clinical information]', 'Factor Value Ontology Term[clinical information]', 'Factor Value[inferred cell type - ontology labels]', 'Factor Value Ontology Term[inferred cell type - ontology labels]'
